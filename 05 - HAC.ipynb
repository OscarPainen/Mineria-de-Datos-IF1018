# %% [markdown]
# # IF-1018 Minería de Datos

# %% [markdown]
# - Versiones de librerías, python 3.8.10
#
# - numpy 1.20.3
# - sklearn 1.0.2
# - matplotlib 3.5.2
# - scipy 1.8.0

# %% [markdown]
# ### Vamos a crear un dendrograma con 50 muestras

# %%
from sklearn import datasets
digits = datasets.load_digits()
X = digits.data[:50,]
y = digits.target[:50,]

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
X = min_max_scaler.fit_transform(X)

# %% [markdown]
# ### Vamos a probar las 4 distancias de clustering aglomerativo

# %%
from sklearn.cluster import AgglomerativeClustering

# DecisionTree - 
# setting distance_threshold=0 ensures we compute the full tree.
hac1 = AgglomerativeClustering(linkage='single', n_clusters=10)
hac1 = hac1.fit(X)

hac2 = AgglomerativeClustering(linkage='average', n_clusters=10)
hac2 = hac2.fit(X)

hac3 = AgglomerativeClustering(linkage='complete', n_clusters=10)
hac3 = hac3.fit(X)

hac4 = AgglomerativeClustering(linkage='ward', n_clusters=10)
hac4 = hac4.fit(X)

# %% [markdown]
# ### Y calculamos el Silhouette para ver cual funcionó mejor

# %%
for i in range(8,14):
    hac1 = AgglomerativeClustering(linkage='single', n_clusters=i)
    hac1 = hac1.fit(X)

    hac2 = AgglomerativeClustering(linkage='average', n_clusters=i)
    hac2 = hac2.fit(X)

    hac3 = AgglomerativeClustering(linkage='complete', n_clusters=i)
    hac3 = hac3.fit(X)

    hac4 = AgglomerativeClustering(linkage='ward', n_clusters=i)
    hac4 = hac4.fit(X)
    print(silhouette_score(X, hac1.labels_, metric="euclidean",))
    print(silhouette_score(X, hac2.labels_, metric="euclidean",))
    print(silhouette_score(X, hac3.labels_, metric="euclidean",))
    print(silhouette_score(X, hac4.labels_, metric="euclidean",))
    print('\n', i)
# Out:
# 0.17325433416506292
# 0.23215278225561028
# 0.2246966347207531
# 0.24620087994881223
#
#  8
# 0.2024105490879088
# 0.2465970076724954
# 0.2237919126353529
# 0.24703209069448412
#
#  9
# 0.22744808295646707
# 0.2660735260395983
# 0.2515476758694331
# 0.2636844668119454
#
#  10
# 0.23571789115151964
# 0.2604127753295537
# 0.2666427919319536
# 0.2729325390892267
#
#  11
# 0.2694333977004609
# 0.2694333977004609
# 0.2572532179700109
# 0.277960408420585
#
#  12
# 0.25188591022173457
# 0.2728334919924878
# 0.264593215203839
# 0.2632050858294168
#
#  13

# %%
from sklearn.metrics import silhouette_score

print(silhouette_score(X, hac1.labels_, metric="euclidean",))
print(silhouette_score(X, hac2.labels_, metric="euclidean",))
print(silhouette_score(X, hac3.labels_, metric="euclidean",))
print(silhouette_score(X, hac4.labels_, metric="euclidean",))
# Out:
# 0.22744808295646707
# 0.2660735260395983
# 0.2515476758694331
# 0.2636844668119454

# %% [markdown]
# ### Nos quedamos con average link

# %%
from sklearn.cluster import AgglomerativeClustering

# setting distance_threshold=0 ensures we compute the full tree.
hac = AgglomerativeClustering(distance_threshold=0,linkage='average', n_clusters=None)
hac = hac.fit(X)

# %% [markdown]
# Ver más configuraciones de hac en: https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html#sklearn.cluster.AgglomerativeClustering

# %% [markdown]
# ### Ahora vamos a visualizar el dendrograma

# %%
import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram

def plot_dendrogram(model, **kwargs):

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0]) 
    n_samples = len(model.labels_) # model.labels_: cluster labels for each point
    for i, merge in enumerate(model.children_): 
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples] # in-order enumeration of nodes
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_, counts]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)
tipos = ['single','average','complete','ward']
for model in tipos:
    hac = AgglomerativeClustering(distance_threshold=0,linkage=model, n_clusters=None)
    hac = hac.fit(X)
    plt.figure(figsize=(8, 14))
    plt.title(f"Hierarchical Clustering Dendrogram - {model}")
    # plot the top three levels of the dendrogram
    plot_dendrogram(hac, truncate_mode="level", p=5, labels=y, orientation = 'left')
    plt.ylabel("Number of points in node (or target of point if no parenthesis).")
    plt.show()
